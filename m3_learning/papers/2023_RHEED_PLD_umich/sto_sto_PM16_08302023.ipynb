# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import glob, re

import sys
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import colors

sys.path.append('../../src')
from m3_learning.nn.random import random_seed
from m3_learning.viz.style import set_style
from m3_learning.RHEED.Analysis_umich import fit_curves, analyze_rheed_data, plot_activation_energy, read_txt_to_numpy, select_range
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = './Saved_data/8-21-2023/STO 650C PeterManualRelaxation (.33Hz-33ms).txt'
data = np.loadtxt(file)
sample_x, sample_y = data[:,0], data[:,1]
plt.figure(figsize=(6, 3))
plt.plot(sample_x, sample_y, color='k', linewidth=1)
plt.xlabel('Time (s)')
plt.ylabel('Intensity (a.u.)')
plt.show()

# %%
file = './Saved_data/rheed_data/PM16_STO/650C_secondorder.txt'
range = (130, 140)
print(file)
header, data = read_txt_to_numpy(file)
data = select_range(data, *range)
sample_x, sample_y = data[:,0], data[:,1]

plt.figure(figsize=(10, 5))
plt.plot(sample_x, sample_y)
plt.show()
# Out:
# ./Saved_data/rheed_data/PM16_STO/650C_secondorder.txt

# %%
for file in glob.glob('./Saved_data/8-21-2023/*.txt'):
    range = (30, 40)
    print(file)
    data = np.loadtxt(file)
    data = select_range(data, *range)
    sample_x, sample_y = data[:,0], data[:,1]

    plt.figure(figsize=(10, 5))
    plt.plot(sample_x, sample_y)
    plt.show()

# %%
tau_list, temp_list = [], []
for file in glob.glob('./Saved_data/rheed_data/PM16_STO/*.txt'):
    print(file)
    header, data = read_txt_to_numpy(file)
    sample_x, sample_y = data[:,0], data[:,1]
    plt.figure(figsize=(10, 5))
    plt.plot(sample_x, sample_y)
    plt.show()
# Out:
# ./Saved_data/rheed_data/PM16_STO\630C_secondorder.txt
# ./Saved_data/rheed_data/PM16_STO\630C_secondorder_2.txt
# ./Saved_data/rheed_data/PM16_STO\650C_secondorder.txt
# ./Saved_data/rheed_data/PM16_STO\650C_secondorder_2.txt
# ./Saved_data/rheed_data/PM16_STO\670C_secondorder.txt
# ./Saved_data/rheed_data/PM16_STO\690C_secondorder.txt
# ./Saved_data/rheed_data/PM16_STO\710C_secondorder.txt
# ./Saved_data/rheed_data/PM16_STO\800C_secondorder.txt

# %%
fit_settings =  {'step_size':5, 'prominence':20, 'savgol_window_order': (15, 3), 'pca_component': 10, 'I_diff': None, 
                'unify':False, 'bounds':[0.001, 1], 'p_init':[0.1, 0.4, 0.1]}
laser_freq = 0.25
camera_freq = 1000/50
viz_curves=False
viz_fittings=False
viz_ab=False

tau_list = []
temp_list = [630, 630, 650, 650, 670, 690, 710, 800]
range_list = [[75, 270], [70, 270], [70, 270], [60, 270],  [55, 270], [55, 270], [55, 270], [70, 270]]

for file, range in zip(glob.glob('./Saved_data/rheed_data/PM16_STO/*.txt')[:1], range_list[:1]):
    print(file)
    header, data = read_txt_to_numpy(file)
    data = select_range(data, *range)
    sample_x, sample_y = data[:,0], data[:,1]

    plt.figure(figsize=(10, 5))
    plt.plot(sample_x, sample_y)
    plt.show()
        
    parameters_all, x_list_all, info, tau = analyze_rheed_data(data, camera_freq, laser_freq, fit_settings, viz_curves, viz_fittings, viz_ab, n_std=1)

    tau_list.append(tau)
# Out:
# ./Saved_data/rheed_data/PM16_STO\630C_secondorder.txt

# %%
fit_settings =  {'step_size':5, 'prominence':20, 'mode':'valid', 'savgol_window_order': (15, 3), 'pca_component': 10, 'I_diff': None, 
                'unify':False, 'bounds':[0.001, 1], 'p_init':[0.1, 0.4, 0.1]}
laser_freq = 0.25
camera_freq = 1000/50
viz_curves=False
viz_fittings=False
viz_ab=False

tau_list = []
temp_list = [630, 630, 650, 650, 670, 690, 710, 800]
range_list = [[75, 270], [70, 270], [70, 270], [60, 270],  [55, 270], [55, 270], [55, 270], [70, 270]]

for file, range in zip(glob.glob('./Saved_data/rheed_data/selected/*.txt'), range_list):
    print(file)
    header, data = read_txt_to_numpy(file)
    data = select_range(data, *range)
    sample_x, sample_y = data[:,0], data[:,1]

    plt.figure(figsize=(10, 5))
    plt.plot(sample_x, sample_y)
    plt.show()
        
    parameters_all, x_list_all, info, tau = analyze_rheed_data(data, camera_freq, laser_freq, fit_settings, viz_curves, viz_fittings, 
                                                                viz_ab, n_std=1)

    tau_list.append(tau)
# Out:
# ./Saved_data/rheed_data/selected\250C_second250shots_secondorder_midgrowth.txt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\yig319\Dropbox (LU Student)\m3_learning\m3_learning\papers\2023_RHEED_PLD_SrTiO3 - UMich\sto_sto_PM16_08302023.ipynb Cell 9 in 2
#      <a href='vscode-notebook-cell:/c%3A/Users/yig319/Dropbox%20%28LU%20Student%29/m3_learning/m3_learning/papers/2023_RHEED_PLD_SrTiO3%20-%20UMich/sto_sto_PM16_08302023.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> plt.plot(sample_x, sample_y)
#      <a href='vscode-notebook-cell:/c%3A/Users/yig319/Dropbox%20%28LU%20Student%29/m3_learning/m3_learning/papers/2023_RHEED_PLD_SrTiO3%20-%20UMich/sto_sto_PM16_08302023.ipynb#X11sZmlsZQ%3D%3D?line=20'>21</a> plt.show()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/yig319/Dropbox%20%28LU%20Student%29/m3_learning/m3_learning/papers/2023_RHEED_PLD_SrTiO3%20-%20UMich/sto_sto_PM16_08302023.ipynb#X11sZmlsZQ%3D%3D?line=22'>23</a> parameters_all, x_list_all, info, tau = analyze_rheed_data(data, camera_freq, laser_freq, fit_settings, viz_curves, viz_fittings,
#      <a href='vscode-notebook-cell:/c%3A/Users/yig319/Dropbox%20%28LU%20Student%29/m3_learning/m3_learning/papers/2023_RHEED_PLD_SrTiO3%20-%20UMich/sto_sto_PM16_08302023.ipynb#X11sZmlsZQ%3D%3D?line=23'>24</a>                                                             viz_ab, n_std=1)
#      <a href='vscode-notebook-cell:/c%3A/Users/yig319/Dropbox%20%28LU%20Student%29/m3_learning/m3_learning/papers/2023_RHEED_PLD_SrTiO3%20-%20UMich/sto_sto_PM16_08302023.ipynb#X11sZmlsZQ%3D%3D?line=25'>26</a> tau_list.append(tau)
#
# File c:\Users\yig319\Dropbox (LU Student)\m3_learning\m3_learning\src\m3_learning\RHEED\Analysis_umich.py:164, in analyze_rheed_data(data, camera_freq, laser_freq, fit_settings, viz_curves, viz_fittings, viz_ab, n_std, trim_first)
#     161     fig, axes = layout_fig(len(ys_sample), mod=6, figsize=(12,2*len(ys_sample)//6+1), layout='compressed')
#     162     Viz.show_grid_plots(axes, xs_sample, ys_sample, labels=None, xlabel=None, ylabel=None, ylim=None, legend=None, color=None)
# --> 164 parameters_all, x_list_all, info = fit_curves(xs, ys, x_peaks, sample_x, fit_settings)
#     165 [xs_all, ys_all, ys_fit_all, ys_nor_all, ys_nor_fit_all, ys_nor_fit_failed_all, labels_all, losses_all] = info
#     167 if viz_fittings:
#
# File c:\Users\yig319\Dropbox (LU Student)\m3_learning\m3_learning\src\m3_learning\RHEED\Analysis_umich.py:110, in fit_curves(xs, ys, x_peaks, sample_x, fit_settings)
#     107 labels_all, losses_all =  [], []
#     109 # fit exponential function
# --> 110 parameters, info = fit_exp_function(xs, ys, growth_name='growth_1', fit_settings=fit_settings)
#     111 parameters_all.append(parameters)
#     112 xs, ys, ys_fit, ys_nor, ys_nor_fit, ys_nor_fit_failed, labels, losses = info
#
# File c:\Users\yig319\Dropbox (LU Student)\m3_learning\m3_learning\src\m3_learning\RHEED\Analysis.py:247, in fit_exp_function(xs, ys, growth_name, fit_settings)
#     244 a1, b1, relax1 = params
#     245 y1_nor_fit = exp_func_inc(x, a1, b1, relax1)
# --> 247 params, params_covariance = curve_fit(exp_func_dec, x, y_nor, p0=p_init, bounds=bounds, absolute_sigma=False)
#     248 a2, b2, relax2 = params
#     249 y2_nor_fit = exp_func_dec(x, a2, b2, relax2)
#
# File c:\Users\yig319\Anaconda3\envs\m3\lib\site-packages\scipy\optimize\_minpack_py.py:849, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     845 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     846                     **kwargs)
#     848 if not res.success:
# --> 849     raise RuntimeError("Optimal parameters not found: " + res.message)
#     851 infodict = dict(nfev=res.nfev, fvec=res.fun)
#     852 ier = res.status
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
plot_activation_energy(temp_list, tau_list)
